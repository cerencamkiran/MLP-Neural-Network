# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("Project1.csv") 

data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
data = data.drop('CustomerId', inplace=False, axis=1)
data = data.drop('RowNumber', inplace=False, axis=1)
data = data.drop('Surname', inplace=False, axis=1)
data
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to categorical columns
data['Gender'] = label_encoder.fit_transform(data['Gender'])
data
#female=0, male=1
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       1   39       5       0.00              2
# 9996          516    France       1   35      10   57369.61              1
# 9997          709    France       0   36       7       0.00              1
# 9998          772   Germany       1   42       3   75075.31              2
# 9999          792    France       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
data['Geography'] = label_encoder.fit_transform(data['Geography'])
data
#Spain:2 Germany:1 France:0
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               1        101348.88       1
# 1             0               1        112542.58       0
# 2             1               0        113931.57       1
# 3             0               0         93826.63       0
# 4             1               1         79084.10       0
# ...         ...             ...              ...     ...
# 9995          1               0         96270.64       0
# 9996          1               1        101699.77       0
# 9997          0               1         42085.58       1
# 9998          1               0         92888.52       1
# 9999          1               0         38190.78       0
#
# [10000 rows x 11 columns]

# %%
data.describe().T
# Out:
#                    count           mean           std     min       25%  \
# CreditScore      10000.0     650.528800     96.653299  350.00    584.00
# Geography        10000.0       0.746300      0.827529    0.00      0.00
# Gender           10000.0       0.545700      0.497932    0.00      0.00
# Age              10000.0      38.921800     10.487806   18.00     32.00
# Tenure           10000.0       5.012800      2.892174    0.00      3.00
# Balance          10000.0   76485.889288  62397.405202    0.00      0.00
# NumOfProducts    10000.0       1.530200      0.581654    1.00      1.00
# HasCrCard        10000.0       0.705500      0.455840    0.00      0.00
# IsActiveMember   10000.0       0.515100      0.499797    0.00      0.00
# EstimatedSalary  10000.0  100090.239881  57510.492818   11.58  51002.11
# Exited           10000.0       0.203700      0.402769    0.00      0.00
#
#                         50%          75%        max
# CreditScore         652.000     718.0000     850.00
# Geography             0.000       1.0000       2.00
# Gender                1.000       1.0000       1.00
# Age                  37.000      44.0000      92.00
# Tenure                5.000       7.0000      10.00
# Balance           97198.540  127644.2400  250898.09
# NumOfProducts         1.000       2.0000       4.00
# HasCrCard             1.000       1.0000       1.00
# IsActiveMember        1.000       1.0000       1.00
# EstimatedSalary  100193.915  149388.2475  199992.48
# Exited                0.000       0.0000       1.00

# %%
data.groupby("Gender").agg({"Age": "mean"})
# Out:
#               Age
# Gender
# 0       39.238389
# 1       38.658237

# %%
data.groupby("Geography").agg({"Exited": "mean"})
# Out:
#              Exited
# Geography
# 0          0.161548
# 1          0.324432
# 2          0.166734

# %%
data.groupby("Gender").agg({"Exited": "mean"})
# Out:
#           Exited
# Gender
# 0       0.250715
# 1       0.164559

# %%
data["Exited"].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
bins=[10,20,30,40,50,60]
labels=['<20','21-30','31-40','41-50','>50']
data['AgeGroup']=pd.cut(data['Age'],bins=bins,labels=labels)
data
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited AgeGroup
# 0             1               1        101348.88       1    41-50
# 1             0               1        112542.58       0    41-50
# 2             1               0        113931.57       1    41-50
# 3             0               0         93826.63       0    31-40
# 4             1               1         79084.10       0    41-50
# ...         ...             ...              ...     ...      ...
# 9995          1               0         96270.64       0    31-40
# 9996          1               1        101699.77       0    31-40
# 9997          0               1         42085.58       1    31-40
# 9998          1               0         92888.52       1    41-50
# 9999          1               0         38190.78       0    21-30
#
# [10000 rows x 12 columns]

# %%
import seaborn as sns
f,ax=plt.subplots(1,2,figsize=(18,8))
data['AgeGroup'].value_counts().plot.pie(explode=[0.1,0.01,0.2,0.1,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Distribution')
ax[0].set_ylabel('')
sns.countplot(data=data, x='AgeGroup', ax=ax[1])
ax[1].set_title('AgeGroup')
plt.show()

# %%
import seaborn as sns
f,ax=plt.subplots(1,2,figsize=(18,8))
data['Exited'].value_counts().plot.pie(explode=[0.1,0.01],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Distribution')
ax[0].set_ylabel('')
sns.countplot(data=data, x='Exited', ax=ax[1])
ax[1].set_title('Exited')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

from sklearn import datasets
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf
from tensorflow import keras

# %%
data = data.drop('AgeGroup', inplace=False, axis=1)

# %%
X
# Out:
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619          0       0   42       2       0.00              1
# 1             608          2       0   41       1   83807.86              1
# 2             502          0       0   42       8  159660.80              3
# 3             699          0       0   39       1       0.00              2
# 4             850          2       0   43       2  125510.82              1
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       1   39       5       0.00              2
# 9996          516          0       1   35      10   57369.61              1
# 9997          709          0       0   36       7       0.00              1
# 9998          772          1       1   42       3   75075.31              2
# 9999          792          0       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# 0             1               1        101348.88
# 1             0               1        112542.58
# 2             1               0        113931.57
# 3             0               0         93826.63
# 4             1               1         79084.10
# ...         ...             ...              ...
# 9995          1               0         96270.64
# 9996          1               1        101699.77
# 9997          0               1         42085.58
# 9998          1               0         92888.52
# 9999          1               0         38190.78
#
# [10000 rows x 10 columns]

# %%
y = data["Exited"]
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %%
X = data.drop('Exited', inplace=False, axis=1)
y = data['Exited']
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.20,
                                                random_state = 1234, shuffle = False)
print(Xtrain.shape, ytrain.shape, Xtest.shape, ytest.shape)
# Out:
# (8000, 10) (8000,) (2000, 10) (2000,)

# %%
lr_model = LinearRegression(fit_intercept = True)
lr_model.fit(Xtrain, ytrain)

print(lr_model.coef_, lr_model.intercept_)
# Out:
# [-8.94226776e-05  9.59852386e-03 -8.40947246e-02  1.16055510e-02
#  -1.73492713e-03  6.76211006e-07 -5.11026725e-03 -7.52087183e-04
#  -1.51904766e-01  8.65063981e-08] -0.11510540425367424

# %%
ytrain_hat = lr_model.predict(Xtrain)
print(mean_squared_error(ytrain, ytrain_hat))
# Out:
# 0.1398259006135869

# %%
ytest_hat = lr_model.predict(Xtest)
print(mean_squared_error(ytest, ytest_hat))
# Out:
# 0.14126426233980363

# %%
# STEP#1: conceptual network
nn_model = keras.models.Sequential([
    keras.layers.Input(shape = (Xtrain.shape[1],)),
    keras.layers.Dense(1)
])
nn_model.summary()

nn_model2 = keras.models.Sequential()
nn_model2.add(keras.layers.Input(shape = (Xtrain.shape[1],)))
nn_model2.add(keras.layers.Dense(1))
nn_model2.summary()

# STEP#2: compiled network
nn_model.compile(optimizer = keras.optimizers.Adam(learning_rate = 0.01),
                 loss = "mean_squared_error")

# STEP#3: learned network
nn_model.fit(Xtrain, ytrain,
             epochs = 20,
             batch_size = 16,
             verbose = 1)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 11
# Trainable params: 11
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 500/500 [==============================] - 1s 2ms/step - loss: 195320352.0000
# Epoch 2/20
# 500/500 [==============================] - 1s 1ms/step - loss: 54150.4258
# Epoch 3/20
# 500/500 [==============================] - 1s 2ms/step - loss: 34532.8281
# Epoch 4/20
# 500/500 [==============================] - 1s 2ms/step - loss: 18317.1133
# Epoch 5/20
# 500/500 [==============================] - 1s 2ms/step - loss: 7690.9048
# Epoch 6/20
# 500/500 [==============================] - 1s 2ms/step - loss: 2483.7488
# Epoch 7/20
# 500/500 [==============================] - 1s 2ms/step - loss: 584.8884
# Epoch 8/20
# 500/500 [==============================] - 1s 2ms/step - loss: 105.3999
# Epoch 9/20
# 500/500 [==============================] - 1s 1ms/step - loss: 31.6010
# Epoch 10/20
# 500/500 [==============================] - 1s 1ms/step - loss: 24.5360
# Epoch 11/20
# 500/500 [==============================] - 1s 2ms/step - loss: 22.8729
# Epoch 12/20
# 500/500 [==============================] - 0s 897us/step - loss: 22.4117
# Epoch 13/20
# 500/500 [==============================] - 0s 981us/step - loss: 22.3521
# Epoch 14/20
# 500/500 [==============================] - 0s 939us/step - loss: 20.7787
# Epoch 15/20
# 500/500 [==============================] - 0s 909us/step - loss: 67.6791
# Epoch 16/20
# 500/500 [==============================] - 0s 983us/step - loss: 306.4538
# Epoch 17/20
# 500/500 [==============================] - 1s 1ms/step - loss: 14663.6025
# Epoch 18/20
# 500/500 [==============================] - 1s 1ms/step - loss: 456.5422
# Epoch 19/20
# 500/500 [==============================] - 1s 2ms/step - loss: 13513.8633
# Epoch 20/20
# 500/500 [==============================] - 1s 2ms/step - loss: 398.6809

# %%
ytrain_hat = nn_model.predict(Xtrain)
print(mean_squared_error(ytrain, ytrain_hat))
ytest_hat = nn_model.predict(Xtest)
print(mean_squared_error(ytest, ytest_hat))
# Out:
# 250/250 [==============================] - 0s 1ms/step
# 9.598162296057705
# 63/63 [==============================] - 0s 788us/step
# 9.188630429676767

# %%
nn_model.weights
# Out:
# [<tf.Variable 'dense_2/kernel:0' shape=(10, 1) dtype=float32, numpy=
#  array([[ 1.6362141e-03],
#         [ 1.6320978e-01],
#         [-3.2432147e-03],
#         [-6.1338428e-02],
#         [ 1.4987341e-01],
#         [-1.2420809e-05],
#         [-3.5989472e-01],
#         [ 5.2497715e-01],
#         [ 5.8151507e-01],
#         [-1.4718067e-05]], dtype=float32)>,
#  <tf.Variable 'dense_2/bias:0' shape=(1,) dtype=float32, numpy=array([0.30743194], dtype=float32)>]

# %%
mlp_model = keras.models.Sequential([
    keras.layers.Dense(32, activation = "relu", input_shape = (Xtrain.shape[1],)),
    keras.layers.Dense(1)
])
mlp_model.summary()

mlp_model2 = keras.models.Sequential([
    keras.layers.Input(shape = (Xtrain.shape[1],)),
    keras.layers.Dense(32, activation = "relu"),
    keras.layers.Dense(1)
])
mlp_model2.summary()

mlp_model3 = keras.models.Sequential([
    keras.layers.Input(shape = (Xtrain.shape[1],)),
    keras.layers.Dense(32),
    keras.layers.Activation("relu"),
    keras.layers.Dense(1)
])
mlp_model3.summary()

# x: 13 => z: 32 => y_hat: 1
# number of connections from x to z = (13 + 1) x 32
# number of connections from z to y_hat = (33 + 1) x 1

mlp_model.compile(loss = "mean_squared_error",
                  optimizer = keras.optimizers.Adam(learning_rate = 0.0001),
                  metrics = ["mae"])

mlp_history = mlp_model.fit(Xtrain, ytrain,
                            epochs = 200,
                            batch_size = 16,
                            verbose = 1)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 32)                352
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 32)                352
#
#  dense_7 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 32)                352
#
#  activation (Activation)     (None, 32)                0
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 500/500 [==============================] - 1s 991us/step - loss: 8718278.0000 - mae: 2153.5625
# Epoch 2/200
# 500/500 [==============================] - 1s 1ms/step - loss: 540349.1250 - mae: 535.6553
# Epoch 3/200
# 500/500 [==============================] - 1s 1ms/step - loss: 96391.2500 - mae: 219.8184
# Epoch 4/200
# 500/500 [==============================] - 1s 1ms/step - loss: 49512.7617 - mae: 161.9311
# Epoch 5/200
# 500/500 [==============================] - 1s 1ms/step - loss: 26825.6289 - mae: 103.6208
# Epoch 6/200
# 500/500 [==============================] - 1s 1ms/step - loss: 18655.5820 - mae: 75.1795
# Epoch 7/200
# 500/500 [==============================] - 1s 1ms/step - loss: 14955.1270 - mae: 63.3841
# Epoch 8/200
# 500/500 [==============================] - 1s 1ms/step - loss: 12228.6738 - mae: 58.9180
# Epoch 9/200
# 500/500 [==============================] - 1s 2ms/step - loss: 9296.8438 - mae: 51.2541
# Epoch 10/200
# 500/500 [==============================] - 1s 1ms/step - loss: 6734.5625 - mae: 41.0416
# Epoch 11/200
# 500/500 [==============================] - 1s 1ms/step - loss: 4854.8818 - mae: 32.5695
# Epoch 12/200
# 500/500 [==============================] - 1s 2ms/step - loss: 3624.0593 - mae: 26.5198
# Epoch 13/200
# 500/500 [==============================] - 1s 2ms/step - loss: 2699.6355 - mae: 23.9738
# Epoch 14/200
# 500/500 [==============================] - 1s 2ms/step - loss: 1929.5620 - mae: 20.5392
# Epoch 15/200
# 500/500 [==============================] - 1s 2ms/step - loss: 1554.4307 - mae: 20.2584
# Epoch 16/200
# 500/500 [==============================] - 1s 2ms/step - loss: 1161.0806 - mae: 17.2996
# Epoch 17/200
# 500/500 [==============================] - 1s 2ms/step - loss: 881.4473 - mae: 14.6124
# Epoch 18/200
# 500/500 [==============================] - 1s 2ms/step - loss: 693.7161 - mae: 13.8539
# Epoch 19/200
# 500/500 [==============================] - 1s 2ms/step - loss: 515.8258 - mae: 12.2440
# Epoch 20/200
# 500/500 [==============================] - 1s 2ms/step - loss: 459.1567 - mae: 12.7303
# Epoch 21/200
# 500/500 [==============================] - 1s 2ms/step - loss: 374.4387 - mae: 12.3222
# Epoch 22/200
# 500/500 [==============================] - 1s 1ms/step - loss: 265.3905 - mae: 10.1024
# Epoch 23/200
# 500/500 [==============================] - 1s 1ms/step - loss: 171.7526 - mae: 7.7811
# Epoch 24/200
# 500/500 [==============================] - 1s 1ms/step - loss: 165.8294 - mae: 7.7436
# Epoch 25/200
# 500/500 [==============================] - 1s 1ms/step - loss: 155.9971 - mae: 8.0873
# Epoch 26/200
# 500/500 [==============================] - 1s 1ms/step - loss: 147.5573 - mae: 8.0242
# Epoch 27/200
# 500/500 [==============================] - 1s 1ms/step - loss: 166.3656 - mae: 8.7479
# Epoch 28/200
# 500/500 [==============================] - 1s 1ms/step - loss: 68.9512 - mae: 5.3247
# Epoch 29/200
# 500/500 [==============================] - 1s 1ms/step - loss: 152.3659 - mae: 7.9065
# Epoch 30/200
# 500/500 [==============================] - 1s 2ms/step - loss: 84.8787 - mae: 6.1729
# Epoch 31/200
# 500/500 [==============================] - 1s 2ms/step - loss: 74.0208 - mae: 5.9391
# Epoch 32/200
# 500/500 [==============================] - 1s 2ms/step - loss: 62.6709 - mae: 5.1387
# Epoch 33/200
# 500/500 [==============================] - 1s 1ms/step - loss: 36.0441 - mae: 4.2903
# Epoch 34/200
# 500/500 [==============================] - 1s 1ms/step - loss: 59.9060 - mae: 5.2705
# Epoch 35/200
# 500/500 [==============================] - 1s 2ms/step - loss: 55.5653 - mae: 4.7494
# Epoch 36/200
# 500/500 [==============================] - 1s 2ms/step - loss: 156.4213 - mae: 6.5062
# Epoch 37/200
# 500/500 [==============================] - 1s 2ms/step - loss: 21.3806 - mae: 3.3918
# Epoch 38/200
# 500/500 [==============================] - 1s 2ms/step - loss: 45.8124 - mae: 4.5679
# Epoch 39/200
# 500/500 [==============================] - 1s 1ms/step - loss: 63.8429 - mae: 5.6134
# Epoch 40/200
# 500/500 [==============================] - 1s 2ms/step - loss: 35.5055 - mae: 4.0653
# Epoch 41/200
# 500/500 [==============================] - 1s 2ms/step - loss: 56.2931 - mae: 4.6921
# Epoch 42/200
# 500/500 [==============================] - 1s 1ms/step - loss: 46.7964 - mae: 4.2795
# Epoch 43/200
# 500/500 [==============================] - 1s 1ms/step - loss: 57.1389 - mae: 5.2392
# Epoch 44/200
# 500/500 [==============================] - 1s 1ms/step - loss: 189.8726 - mae: 6.4331
# Epoch 45/200
# 500/500 [==============================] - 1s 1ms/step - loss: 22.9317 - mae: 3.3088
# Epoch 46/200
# 500/500 [==============================] - 1s 1ms/step - loss: 41.1408 - mae: 4.4685
# Epoch 47/200
# 500/500 [==============================] - 1s 1ms/step - loss: 32.7585 - mae: 4.1304
# Epoch 48/200
# 500/500 [==============================] - 1s 1ms/step - loss: 57.0598 - mae: 4.7902
# Epoch 49/200
# 500/500 [==============================] - 1s 1ms/step - loss: 40.6097 - mae: 3.8225
# Epoch 50/200
# 500/500 [==============================] - 1s 1ms/step - loss: 20.2985 - mae: 3.1364
# Epoch 51/200
# 500/500 [==============================] - 1s 1ms/step - loss: 102.0118 - mae: 5.2337
# Epoch 52/200
# 500/500 [==============================] - 1s 2ms/step - loss: 20.4315 - mae: 2.9683
# Epoch 53/200
# 500/500 [==============================] - 1s 2ms/step - loss: 87.6779 - mae: 6.2914
# Epoch 54/200
# 500/500 [==============================] - 1s 2ms/step - loss: 56.5914 - mae: 4.6028
# Epoch 55/200
# 500/500 [==============================] - 1s 2ms/step - loss: 39.0564 - mae: 3.7992
# Epoch 56/200
# 500/500 [==============================] - 1s 2ms/step - loss: 16.5170 - mae: 2.8132
# Epoch 57/200
# 500/500 [==============================] - 1s 2ms/step - loss: 91.0531 - mae: 5.3903
# Epoch 58/200
# 500/500 [==============================] - 1s 2ms/step - loss: 26.2389 - mae: 3.5465
# Epoch 59/200
# 500/500 [==============================] - 1s 1ms/step - loss: 49.1959 - mae: 4.5106
# Epoch 60/200
# 500/500 [==============================] - 1s 1ms/step - loss: 91.4173 - mae: 4.8801
# Epoch 61/200
# 500/500 [==============================] - 1s 1ms/step - loss: 55.0921 - mae: 4.2899
# Epoch 62/200
# 500/500 [==============================] - 1s 1ms/step - loss: 91.1502 - mae: 5.4384
# Epoch 63/200
# 500/500 [==============================] - 1s 2ms/step - loss: 43.5318 - mae: 3.3431
# Epoch 64/200
# 500/500 [==============================] - 1s 2ms/step - loss: 132.5527 - mae: 5.2577
# Epoch 65/200
# 500/500 [==============================] - 1s 2ms/step - loss: 7.3608 - mae: 1.8107
# Epoch 66/200
# 500/500 [==============================] - 1s 1ms/step - loss: 145.7817 - mae: 5.5580
# Epoch 67/200
# 500/500 [==============================] - 1s 1ms/step - loss: 126.6359 - mae: 3.6188
# Epoch 68/200
# 500/500 [==============================] - 1s 1ms/step - loss: 9.1131 - mae: 2.0670
# Epoch 69/200
# 500/500 [==============================] - 1s 1ms/step - loss: 10.9637 - mae: 2.2839
# Epoch 70/200
# 500/500 [==============================] - 1s 1ms/step - loss: 38.3141 - mae: 3.9491
# Epoch 71/200
# 500/500 [==============================] - 1s 1ms/step - loss: 69.9913 - mae: 5.4934
# Epoch 72/200
# 500/500 [==============================] - 1s 1ms/step - loss: 26.5479 - mae: 3.5904
# Epoch 73/200
# 500/500 [==============================] - 1s 1ms/step - loss: 103.8132 - mae: 6.5984
# Epoch 74/200
# 500/500 [==============================] - 1s 1ms/step - loss: 17.6196 - mae: 2.8932
# Epoch 75/200
# 500/500 [==============================] - 1s 2ms/step - loss: 73.2952 - mae: 5.0697
# Epoch 76/200
# 500/500 [==============================] - 1s 2ms/step - loss: 109.3741 - mae: 5.1632
# Epoch 77/200
# 500/500 [==============================] - 1s 2ms/step - loss: 98.1397 - mae: 4.3899
# Epoch 78/200
# 500/500 [==============================] - 1s 1ms/step - loss: 27.6262 - mae: 2.9622
# Epoch 79/200
# 500/500 [==============================] - 1s 1ms/step - loss: 15.1885 - mae: 2.7262
# Epoch 80/200
# 500/500 [==============================] - 1s 1ms/step - loss: 75.5419 - mae: 4.1698
# Epoch 81/200
# 500/500 [==============================] - 1s 2ms/step - loss: 91.1835 - mae: 4.9408
# Epoch 82/200
# 500/500 [==============================] - 1s 2ms/step - loss: 12.0067 - mae: 2.2252
# Epoch 83/200
# 500/500 [==============================] - 1s 2ms/step - loss: 14.2033 - mae: 2.4896
# Epoch 84/200
# 500/500 [==============================] - 1s 1ms/step - loss: 74.7970 - mae: 6.0416
# Epoch 85/200
# 500/500 [==============================] - 1s 1ms/step - loss: 68.9630 - mae: 5.0538
# Epoch 86/200
# 500/500 [==============================] - 1s 1ms/step - loss: 13.6680 - mae: 2.3815
# Epoch 87/200
# 500/500 [==============================] - 1s 2ms/step - loss: 174.2225 - mae: 6.6622
# Epoch 88/200
# 500/500 [==============================] - 1s 2ms/step - loss: 6.1586 - mae: 1.6660
# Epoch 89/200
# 500/500 [==============================] - 1s 1ms/step - loss: 40.6170 - mae: 4.3617
# Epoch 90/200
# 500/500 [==============================] - 1s 1ms/step - loss: 77.9646 - mae: 4.6156
# Epoch 91/200
# 500/500 [==============================] - 1s 1ms/step - loss: 28.1106 - mae: 3.3518
# Epoch 92/200
# 500/500 [==============================] - 1s 1ms/step - loss: 27.9033 - mae: 3.1782
# Epoch 93/200
# 500/500 [==============================] - 1s 1ms/step - loss: 127.9836 - mae: 6.1899
# Epoch 94/200
# 500/500 [==============================] - 1s 1ms/step - loss: 25.1569 - mae: 3.3099
# Epoch 95/200
# 500/500 [==============================] - 1s 1ms/step - loss: 100.5384 - mae: 5.3632
# Epoch 96/200
# 500/500 [==============================] - 1s 2ms/step - loss: 6.9334 - mae: 1.7461
# Epoch 97/200
# 500/500 [==============================] - 1s 2ms/step - loss: 134.9567 - mae: 5.2253
# Epoch 98/200
# 500/500 [==============================] - 1s 2ms/step - loss: 6.2120 - mae: 1.6343
# Epoch 99/200
# 500/500 [==============================] - 1s 2ms/step - loss: 112.9253 - mae: 6.9181
# Epoch 100/200
# 500/500 [==============================] - 1s 2ms/step - loss: 13.7870 - mae: 2.4198
# Epoch 101/200
# 500/500 [==============================] - 1s 2ms/step - loss: 59.9103 - mae: 4.8259
# Epoch 102/200
# 500/500 [==============================] - 1s 1ms/step - loss: 176.7109 - mae: 6.5992
# Epoch 103/200
# 500/500 [==============================] - 1s 1ms/step - loss: 6.0148 - mae: 1.5738
# Epoch 104/200
# 500/500 [==============================] - 1s 1ms/step - loss: 8.6245 - mae: 1.8687
# Epoch 105/200
# 500/500 [==============================] - 1s 1ms/step - loss: 48.4584 - mae: 4.4619
# Epoch 106/200
# 500/500 [==============================] - 1s 2ms/step - loss: 26.3522 - mae: 3.0058
# Epoch 107/200
# 500/500 [==============================] - 1s 2ms/step - loss: 79.0057 - mae: 5.2364
# Epoch 108/200
# 500/500 [==============================] - 1s 1ms/step - loss: 13.3299 - mae: 2.5178
# Epoch 109/200
# 500/500 [==============================] - 1s 2ms/step - loss: 66.4140 - mae: 4.8540
# Epoch 110/200
# 500/500 [==============================] - 1s 1ms/step - loss: 252.3577 - mae: 6.4824
# Epoch 111/200
# 500/500 [==============================] - 1s 1ms/step - loss: 5.1572 - mae: 1.3966
# Epoch 112/200
# 500/500 [==============================] - 1s 1ms/step - loss: 65.2759 - mae: 4.0962
# Epoch 113/200
# 500/500 [==============================] - 1s 1ms/step - loss: 16.2991 - mae: 2.7057
# Epoch 114/200
# 500/500 [==============================] - 1s 1ms/step - loss: 49.3693 - mae: 4.5630
# Epoch 115/200
# 500/500 [==============================] - 1s 1ms/step - loss: 124.3719 - mae: 5.6059
# Epoch 116/200
# 500/500 [==============================] - 1s 1ms/step - loss: 8.2041 - mae: 1.8785
# Epoch 117/200
# 500/500 [==============================] - 1s 2ms/step - loss: 50.6665 - mae: 4.6157
# Epoch 118/200
# 500/500 [==============================] - 1s 2ms/step - loss: 45.5133 - mae: 4.0462
# Epoch 119/200
# 500/500 [==============================] - 1s 2ms/step - loss: 15.2017 - mae: 2.5627
# Epoch 120/200
# 500/500 [==============================] - 1s 2ms/step - loss: 89.0368 - mae: 5.5535
# Epoch 121/200
# 500/500 [==============================] - 1s 1ms/step - loss: 15.3372 - mae: 2.5133
# Epoch 122/200
# 500/500 [==============================] - 1s 2ms/step - loss: 61.7643 - mae: 4.8959
# Epoch 123/200
# 500/500 [==============================] - 1s 2ms/step - loss: 38.1032 - mae: 4.1489
# Epoch 124/200
# 500/500 [==============================] - 1s 2ms/step - loss: 68.7297 - mae: 4.8117
# Epoch 125/200
# 500/500 [==============================] - 1s 2ms/step - loss: 90.3515 - mae: 4.2944
# Epoch 126/200
# 500/500 [==============================] - 1s 1ms/step - loss: 10.8737 - mae: 2.2181
# Epoch 127/200
# 500/500 [==============================] - 1s 2ms/step - loss: 41.3571 - mae: 3.8187
# Epoch 128/200
# 500/500 [==============================] - 1s 2ms/step - loss: 89.5943 - mae: 5.1983
# Epoch 129/200
# 500/500 [==============================] - 1s 2ms/step - loss: 35.4959 - mae: 4.0864
# Epoch 130/200
# 500/500 [==============================] - 1s 1ms/step - loss: 14.8736 - mae: 2.6983
# Epoch 131/200
# 500/500 [==============================] - 1s 1ms/step - loss: 110.0634 - mae: 4.8394
# Epoch 132/200
# 500/500 [==============================] - 1s 1ms/step - loss: 13.5908 - mae: 2.5626
# Epoch 133/200
# 500/500 [==============================] - 1s 1ms/step - loss: 30.2072 - mae: 3.9063
# Epoch 134/200
# 500/500 [==============================] - 1s 1ms/step - loss: 113.7695 - mae: 5.7586
# Epoch 135/200
# 500/500 [==============================] - 1s 1ms/step - loss: 7.4698 - mae: 1.8607
# Epoch 136/200
# 500/500 [==============================] - 1s 1ms/step - loss: 73.6989 - mae: 4.9562
# Epoch 137/200
# 500/500 [==============================] - 1s 1ms/step - loss: 22.6385 - mae: 2.7385
# Epoch 138/200
# 500/500 [==============================] - 1s 1ms/step - loss: 88.4449 - mae: 4.5335
# Epoch 139/200
# 500/500 [==============================] - 1s 2ms/step - loss: 16.9310 - mae: 2.3712
# Epoch 140/200
# 500/500 [==============================] - 1s 2ms/step - loss: 14.5288 - mae: 2.4603
# Epoch 141/200
# 500/500 [==============================] - 1s 2ms/step - loss: 134.1881 - mae: 7.8016
# Epoch 142/200
# 500/500 [==============================] - 1s 2ms/step - loss: 39.7512 - mae: 4.0591
# Epoch 143/200
# 500/500 [==============================] - 1s 2ms/step - loss: 14.5231 - mae: 2.7484
# Epoch 144/200
# 500/500 [==============================] - 1s 2ms/step - loss: 26.0137 - mae: 3.3290
# Epoch 145/200
# 500/500 [==============================] - 1s 2ms/step - loss: 156.8654 - mae: 7.0728
# Epoch 146/200
# 500/500 [==============================] - 1s 2ms/step - loss: 14.8380 - mae: 2.4090
# Epoch 147/200
# 500/500 [==============================] - 1s 2ms/step - loss: 11.2411 - mae: 2.2028
# Epoch 148/200
# 500/500 [==============================] - 1s 2ms/step - loss: 76.6576 - mae: 5.7224
# Epoch 149/200
# 500/500 [==============================] - 1s 2ms/step - loss: 96.1396 - mae: 6.0976
# Epoch 150/200
# 500/500 [==============================] - 1s 2ms/step - loss: 14.0851 - mae: 2.1914
# Epoch 151/200
# 500/500 [==============================] - 1s 1ms/step - loss: 30.9064 - mae: 3.5526
# Epoch 152/200
# 500/500 [==============================] - 1s 1ms/step - loss: 54.2374 - mae: 4.6753
# Epoch 153/200
# 500/500 [==============================] - 1s 1ms/step - loss: 39.1098 - mae: 4.0222
# Epoch 154/200
# 500/500 [==============================] - 1s 1ms/step - loss: 55.4108 - mae: 4.5162
# Epoch 155/200
# 500/500 [==============================] - 1s 1ms/step - loss: 39.9369 - mae: 2.8822
# Epoch 156/200
# 500/500 [==============================] - 1s 1ms/step - loss: 138.6402 - mae: 5.3923
# Epoch 157/200
# 500/500 [==============================] - 1s 1ms/step - loss: 7.3811 - mae: 1.7908
# Epoch 158/200
# 500/500 [==============================] - 1s 2ms/step - loss: 93.2052 - mae: 4.7110
# Epoch 159/200
# 500/500 [==============================] - 1s 2ms/step - loss: 69.7470 - mae: 4.0377
# Epoch 160/200
# 500/500 [==============================] - 1s 2ms/step - loss: 5.4023 - mae: 1.5771
# Epoch 161/200
# 500/500 [==============================] - 1s 2ms/step - loss: 25.1764 - mae: 2.8902
# Epoch 162/200
# 500/500 [==============================] - 1s 2ms/step - loss: 63.3453 - mae: 4.6908
# Epoch 163/200
# 500/500 [==============================] - 1s 2ms/step - loss: 41.8574 - mae: 4.2497
# Epoch 164/200
# 500/500 [==============================] - 1s 2ms/step - loss: 271.0206 - mae: 8.8211
# Epoch 165/200
# 500/500 [==============================] - 1s 2ms/step - loss: 5.8690 - mae: 1.6892
# Epoch 166/200
# 500/500 [==============================] - 1s 2ms/step - loss: 4.6535 - mae: 1.3525
# Epoch 167/200
# 500/500 [==============================] - 1s 2ms/step - loss: 17.4518 - mae: 2.8907
# Epoch 168/200
# 500/500 [==============================] - 1s 2ms/step - loss: 30.3099 - mae: 3.7314
# Epoch 169/200
# 500/500 [==============================] - 1s 2ms/step - loss: 79.3487 - mae: 4.0724
# Epoch 170/200
# 500/500 [==============================] - 1s 2ms/step - loss: 41.4898 - mae: 4.2215
# Epoch 171/200
# 500/500 [==============================] - 1s 2ms/step - loss: 21.4381 - mae: 3.1247
# Epoch 172/200
# 500/500 [==============================] - 1s 1ms/step - loss: 75.1210 - mae: 4.6586
# Epoch 173/200
# 500/500 [==============================] - 1s 1ms/step - loss: 24.4826 - mae: 3.1849
# Epoch 174/200
# 500/500 [==============================] - 1s 1ms/step - loss: 156.2290 - mae: 5.4343
# Epoch 175/200
# 500/500 [==============================] - 1s 2ms/step - loss: 7.1490 - mae: 1.8781
# Epoch 176/200
# 500/500 [==============================] - 1s 2ms/step - loss: 34.5624 - mae: 3.6889
# Epoch 177/200
# 500/500 [==============================] - 1s 1ms/step - loss: 66.7570 - mae: 4.6681
# Epoch 178/200
# 500/500 [==============================] - 1s 1ms/step - loss: 177.2935 - mae: 6.2051
# Epoch 179/200
# 500/500 [==============================] - 1s 1ms/step - loss: 3.6188 - mae: 1.2247
# Epoch 180/200
# 500/500 [==============================] - 1s 1ms/step - loss: 5.5787 - mae: 1.5607
# Epoch 181/200
# 500/500 [==============================] - 1s 2ms/step - loss: 124.1760 - mae: 5.0843
# Epoch 182/200
# 500/500 [==============================] - 1s 2ms/step - loss: 11.3342 - mae: 2.1003
# Epoch 183/200
# 500/500 [==============================] - 1s 2ms/step - loss: 11.8778 - mae: 2.1714
# Epoch 184/200
# 500/500 [==============================] - 1s 2ms/step - loss: 27.4424 - mae: 3.3007
# Epoch 185/200
# 500/500 [==============================] - 1s 2ms/step - loss: 130.0106 - mae: 7.1227
# Epoch 186/200
# 500/500 [==============================] - 1s 2ms/step - loss: 6.2283 - mae: 1.7320
# Epoch 187/200
# 500/500 [==============================] - 1s 2ms/step - loss: 92.8844 - mae: 5.8497
# Epoch 188/200
# 500/500 [==============================] - 1s 2ms/step - loss: 11.5495 - mae: 2.3197
# Epoch 189/200
# 500/500 [==============================] - 1s 1ms/step - loss: 62.3575 - mae: 4.6218
# Epoch 190/200
# 500/500 [==============================] - 1s 2ms/step - loss: 38.0350 - mae: 3.7815
# Epoch 191/200
# 500/500 [==============================] - 1s 1ms/step - loss: 53.8076 - mae: 3.9502
# Epoch 192/200
# 500/500 [==============================] - 1s 1ms/step - loss: 36.1972 - mae: 4.0155
# Epoch 193/200
# 500/500 [==============================] - 1s 1ms/step - loss: 48.6001 - mae: 4.6686
# Epoch 194/200
# 500/500 [==============================] - 1s 1ms/step - loss: 23.9579 - mae: 3.3729
# Epoch 195/200
# 500/500 [==============================] - 1s 1ms/step - loss: 71.8846 - mae: 4.7799
# Epoch 196/200
# 500/500 [==============================] - 1s 1ms/step - loss: 41.6861 - mae: 4.1265
# Epoch 197/200
# 500/500 [==============================] - 1s 1ms/step - loss: 34.1792 - mae: 3.8522
# Epoch 198/200
# 500/500 [==============================] - 1s 2ms/step - loss: 214.4955 - mae: 7.7907
# Epoch 199/200
# 500/500 [==============================] - 1s 2ms/step - loss: 3.7687 - mae: 1.2367
# Epoch 200/200
# 500/500 [==============================] - 1s 2ms/step - loss: 6.7157 - mae: 1.8203

# %%
ytrain_hat = mlp_model.predict(Xtrain)
print(mean_squared_error(ytrain, ytrain_hat))
ytest_hat = mlp_model.predict(Xtest)
print(mean_squared_error(ytest, ytest_hat))
# Out:
# 250/250 [==============================] - 0s 929us/step
# 23.605304733979878
# 63/63 [==============================] - 0s 772us/step
# 23.61951815009334

# %%
plt.plot(mlp_history.history["loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
plt.plot(mlp_history.history["mae"])
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.show()

# %%
Xlearn, Xvalidation, ylearn, yvalidation = train_test_split(Xtrain, ytrain, test_size = 0.25,
                                                            random_state = 1234, shuffle = True)
print(Xlearn.shape, ylearn.shape, Xvalidation.shape, yvalidation.shape)

mlp_model = keras.models.Sequential([
    keras.layers.Dense(32, activation = "relu", input_shape = (Xtrain.shape[1],)),
    keras.layers.Dense(1)
])
mlp_model.summary()

mlp_model.compile(loss = "mean_squared_error",
                  optimizer = keras.optimizers.Adam(learning_rate = 0.02),
                  metrics = ["mae"])

mlp_history = mlp_model.fit(Xlearn, ylearn,
                            epochs = 200,
                            batch_size = 16,
                            verbose = 0, 
                            validation_data = (Xvalidation, yvalidation))
# Out:
# (6000, 10) (6000,) (2000, 10) (2000,)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 32)                352
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.plot(mlp_history.history["loss"])
plt.plot(mlp_history.history["val_loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
plt.plot(mlp_history.history["mae"])
plt.plot(mlp_history.history["val_mae"])
plt.xlabel("Epoch")
plt.ylabel("MAE")
plt.show()

# %%
Xlearn, Xvalidation, ylearn, yvalidation = train_test_split(Xtrain, ytrain, test_size = 0.25,
                                                            random_state = 1234, shuffle = True)
print(Xlearn.shape, ylearn.shape, Xvalidation.shape, yvalidation.shape)

# to reduce the risk of overfitting we stop the algorithm if the validation performance
# does not improve in "patience" successive iterations
early_stopping1 = keras.callbacks.EarlyStopping(monitor = "val_loss", 
                                               patience = 10, restore_best_weights = True)
early_stopping2 = keras.callbacks.EarlyStopping(monitor = "val_mae", 
                                               patience = 10, restore_best_weights = True)

mlp_model = keras.models.Sequential([
    keras.layers.Dense(32, name = "hidden", activation = "relu", input_shape = (Xtrain.shape[1],)),
    keras.layers.Dense(1, name = "output")
])
mlp_model.summary()

mlp_model.compile(loss = "mean_squared_error",
                  optimizer = keras.optimizers.Adam(learning_rate = 0.02),
                  metrics = ["mae"])

mlp_history = mlp_model.fit(Xlearn, ylearn,
                            epochs = 200,
                            batch_size = 16,
                            verbose = 1, 
                            callbacks = [early_stopping1, early_stopping2],
                            validation_data = (Xvalidation, yvalidation))
# Out:
# (6000, 10) (6000,) (2000, 10) (2000,)
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 32)                352
#
#  output (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 375/375 [==============================] - 1s 2ms/step - loss: 14271848.0000 - mae: 1090.5127 - val_loss: 33696.1641 - val_mae: 130.9351
# Epoch 2/200
# 375/375 [==============================] - 1s 2ms/step - loss: 21286.7578 - mae: 97.5417 - val_loss: 55338.9531 - val_mae: 209.6562
# Epoch 3/200
# 375/375 [==============================] - 1s 2ms/step - loss: 8768.4082 - mae: 63.6176 - val_loss: 2692.0312 - val_mae: 34.9047
# Epoch 4/200
# 375/375 [==============================] - 1s 2ms/step - loss: 8114.1460 - mae: 62.6504 - val_loss: 16495.9453 - val_mae: 109.4546
# Epoch 5/200
# 375/375 [==============================] - 1s 2ms/step - loss: 892441.2500 - mae: 450.3260 - val_loss: 1306112.1250 - val_mae: 966.0898
# Epoch 6/200
# 375/375 [==============================] - 1s 2ms/step - loss: 318094.2500 - mae: 328.4872 - val_loss: 9454.5840 - val_mae: 62.9620
# Epoch 7/200
# 375/375 [==============================] - 1s 2ms/step - loss: 1111569.3750 - mae: 527.2573 - val_loss: 312049.2188 - val_mae: 502.2560
# Epoch 8/200
# 375/375 [==============================] - 1s 2ms/step - loss: 79612.0234 - mae: 151.8048 - val_loss: 82983.5234 - val_mae: 246.0101
# Epoch 9/200
# 375/375 [==============================] - 1s 2ms/step - loss: 48256.4492 - mae: 128.5053 - val_loss: 13323.4951 - val_mae: 82.9695
# Epoch 10/200
# 375/375 [==============================] - 1s 2ms/step - loss: 432703.7812 - mae: 315.9230 - val_loss: 7300.9922 - val_mae: 58.3126
# Epoch 11/200
# 375/375 [==============================] - 1s 2ms/step - loss: 13965.0479 - mae: 81.9235 - val_loss: 2580.6323 - val_mae: 30.2948
# Epoch 12/200
# 375/375 [==============================] - 1s 2ms/step - loss: 55454.0859 - mae: 134.4813 - val_loss: 4515.8320 - val_mae: 54.5583
# Epoch 13/200
# 375/375 [==============================] - 1s 1ms/step - loss: 18648.3340 - mae: 86.9695 - val_loss: 11158.8506 - val_mae: 80.6123
# Epoch 14/200
# 375/375 [==============================] - 1s 2ms/step - loss: 177687.7031 - mae: 225.2322 - val_loss: 8123.1499 - val_mae: 70.1920
# Epoch 15/200
# 375/375 [==============================] - 1s 2ms/step - loss: 32251.9414 - mae: 119.2043 - val_loss: 4815.9634 - val_mae: 49.8018
# Epoch 16/200
# 375/375 [==============================] - 1s 1ms/step - loss: 46988.5938 - mae: 128.3374 - val_loss: 3029.3997 - val_mae: 42.5378
# Epoch 17/200
# 375/375 [==============================] - 1s 2ms/step - loss: 8610.4502 - mae: 52.8539 - val_loss: 5266.5005 - val_mae: 65.0941
# Epoch 18/200
# 375/375 [==============================] - 1s 2ms/step - loss: 20503.9648 - mae: 72.9421 - val_loss: 1427.3624 - val_mae: 34.2721
# Epoch 19/200
# 375/375 [==============================] - 1s 2ms/step - loss: 15944.7070 - mae: 78.5682 - val_loss: 333977.5312 - val_mae: 492.7697
# Epoch 20/200
# 375/375 [==============================] - 1s 2ms/step - loss: 37565.6367 - mae: 111.9827 - val_loss: 26116.8574 - val_mae: 143.3971
# Epoch 21/200
# 375/375 [==============================] - 1s 1ms/step - loss: 39584.2422 - mae: 109.8445 - val_loss: 274.9892 - val_mae: 13.5514
# Epoch 22/200
# 375/375 [==============================] - 1s 2ms/step - loss: 76.7177 - mae: 6.2939 - val_loss: 16.2828 - val_mae: 2.8012
# Epoch 23/200
# 375/375 [==============================] - 1s 2ms/step - loss: 88.9504 - mae: 6.2763 - val_loss: 14.1420 - val_mae: 2.7025
# Epoch 24/200
# 375/375 [==============================] - 1s 2ms/step - loss: 4248.2534 - mae: 37.0210 - val_loss: 97.5201 - val_mae: 7.9415
# Epoch 25/200
# 375/375 [==============================] - 1s 2ms/step - loss: 13005.7637 - mae: 49.2652 - val_loss: 396.4719 - val_mae: 14.5511
# Epoch 26/200
# 375/375 [==============================] - 1s 2ms/step - loss: 92.2515 - mae: 6.3989 - val_loss: 78.8555 - val_mae: 7.7304
# Epoch 27/200
# 375/375 [==============================] - 1s 3ms/step - loss: 15.8683 - mae: 2.8045 - val_loss: 4.7638 - val_mae: 1.3170
# Epoch 28/200
# 375/375 [==============================] - 1s 2ms/step - loss: 31.7067 - mae: 4.0794 - val_loss: 292.4875 - val_mae: 15.8651
# Epoch 29/200
# 375/375 [==============================] - 1s 2ms/step - loss: 6721.3638 - mae: 35.0104 - val_loss: 16.6805 - val_mae: 3.0320
# Epoch 30/200
# 375/375 [==============================] - 1s 2ms/step - loss: 8.4261 - mae: 2.0423 - val_loss: 7.6622 - val_mae: 1.9200
# Epoch 31/200
# 375/375 [==============================] - 1s 2ms/step - loss: 5.0789 - mae: 1.5894 - val_loss: 2.8118 - val_mae: 1.1232
# Epoch 32/200
# 375/375 [==============================] - 1s 2ms/step - loss: 3.5023 - mae: 1.3402 - val_loss: 2.6929 - val_mae: 1.3176
# Epoch 33/200
# 375/375 [==============================] - 1s 2ms/step - loss: 2.6933 - mae: 1.2046 - val_loss: 1.5332 - val_mae: 0.8769
# Epoch 34/200
# 375/375 [==============================] - 1s 3ms/step - loss: 5.1525 - mae: 1.6213 - val_loss: 2.3205 - val_mae: 1.2542
# Epoch 35/200
# 375/375 [==============================] - 1s 1ms/step - loss: 4.1198 - mae: 1.4204 - val_loss: 1.6824 - val_mae: 1.0748
# Epoch 36/200
# 375/375 [==============================] - 0s 1ms/step - loss: 137.5358 - mae: 6.7419 - val_loss: 49.0240 - val_mae: 6.4477
# Epoch 37/200
# 375/375 [==============================] - 1s 1ms/step - loss: 89.6993 - mae: 5.9701 - val_loss: 2.6844 - val_mae: 1.3135
# Epoch 38/200
# 375/375 [==============================] - 1s 1ms/step - loss: 52.2549 - mae: 4.0430 - val_loss: 1.4651 - val_mae: 0.7716
# Epoch 39/200
# 375/375 [==============================] - 1s 1ms/step - loss: 143.0959 - mae: 7.5795 - val_loss: 135.5182 - val_mae: 9.4357
# Epoch 40/200
# 375/375 [==============================] - 1s 3ms/step - loss: 21.5274 - mae: 2.9060 - val_loss: 19.2603 - val_mae: 3.7229
# Epoch 41/200
# 375/375 [==============================] - 2s 5ms/step - loss: 81.9046 - mae: 5.0882 - val_loss: 0.5672 - val_mae: 0.5945
# Epoch 42/200
# 375/375 [==============================] - 2s 5ms/step - loss: 0.9444 - mae: 0.6287 - val_loss: 0.2543 - val_mae: 0.3428
# Epoch 43/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3803 - mae: 0.4459 - val_loss: 0.1946 - val_mae: 0.3720
# Epoch 44/200
# 375/375 [==============================] - 1s 2ms/step - loss: 2.2730 - mae: 0.8279 - val_loss: 1.3455 - val_mae: 0.8397
# Epoch 45/200
# 375/375 [==============================] - 1s 2ms/step - loss: 1.2764 - mae: 0.6668 - val_loss: 0.6603 - val_mae: 0.5912
# Epoch 46/200
# 375/375 [==============================] - 1s 3ms/step - loss: 36.8409 - mae: 1.3691 - val_loss: 0.2113 - val_mae: 0.3776
# Epoch 47/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.2320 - mae: 0.3727 - val_loss: 0.1620 - val_mae: 0.3190
# Epoch 48/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3744 - mae: 0.4485 - val_loss: 0.2185 - val_mae: 0.4267
# Epoch 49/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.3057 - mae: 0.4139 - val_loss: 0.1574 - val_mae: 0.3151
# Epoch 50/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.3935 - mae: 0.4454 - val_loss: 1.3142 - val_mae: 0.8312
# Epoch 51/200
# 375/375 [==============================] - 1s 2ms/step - loss: 1.1605 - mae: 0.5355 - val_loss: 0.2577 - val_mae: 0.3797
# Epoch 52/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.4169 - mae: 0.4556 - val_loss: 0.1733 - val_mae: 0.3579
# Epoch 53/200
# 375/375 [==============================] - 0s 1ms/step - loss: 0.2424 - mae: 0.3891 - val_loss: 0.3003 - val_mae: 0.4683
# Epoch 54/200
# 375/375 [==============================] - 1s 1ms/step - loss: 0.7835 - mae: 0.5089 - val_loss: 0.2405 - val_mae: 0.4330
# Epoch 55/200
# 375/375 [==============================] - 1s 1ms/step - loss: 0.1730 - mae: 0.3366 - val_loss: 0.1623 - val_mae: 0.3047
# Epoch 56/200
# 375/375 [==============================] - 1s 1ms/step - loss: 0.1666 - mae: 0.3317 - val_loss: 0.1638 - val_mae: 0.3366
# Epoch 57/200
# 375/375 [==============================] - 1s 1ms/step - loss: 0.1709 - mae: 0.3312 - val_loss: 0.1587 - val_mae: 0.3378
# Epoch 58/200
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1691 - mae: 0.3316 - val_loss: 0.1573 - val_mae: 0.3194
# Epoch 59/200
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1698 - mae: 0.3328 - val_loss: 0.1771 - val_mae: 0.3215
# Epoch 60/200
# 375/375 [==============================] - 2s 5ms/step - loss: 0.1669 - mae: 0.3276 - val_loss: 0.1571 - val_mae: 0.3171
# Epoch 61/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1660 - mae: 0.3273 - val_loss: 0.1587 - val_mae: 0.3304
# Epoch 62/200
# 375/375 [==============================] - 1s 1ms/step - loss: 0.1645 - mae: 0.3266 - val_loss: 0.1577 - val_mae: 0.3176
# Epoch 63/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1646 - mae: 0.3257 - val_loss: 0.1567 - val_mae: 0.3158
# Epoch 64/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1647 - mae: 0.3268 - val_loss: 0.1589 - val_mae: 0.3315
# Epoch 65/200
# 375/375 [==============================] - 1s 2ms/step - loss: 0.1648 - mae: 0.3276 - val_loss: 0.1601 - val_mae: 0.3380

# %%
#mlp_model.layers[0].weights
type(mlp_model.layers)

#mlp_model.layers[1]

#mlp_model.layers[0].trainable = False
# Out:
# list

# %%
print(mlp_model.weights[0].numpy().shape)
# Out:
# (10, 32)

# %%
Xlearn, Xvalidation, ylearn, yvalidation = train_test_split(Xtrain, ytrain, test_size = 0.25,
                                                            random_state = 1234, shuffle = True)
print(Xlearn.shape, ylearn.shape, Xvalidation.shape, yvalidation.shape)

mlp_model = keras.models.Sequential([
    keras.layers.Dense(32, name = "hidden", activation = "relu", input_shape = (Xtrain.shape[1],)),
    keras.layers.Dense(1, name = "output")
])
mlp_model.summary()

mlp_model.compile(loss = "mean_squared_error",
                  optimizer = keras.optimizers.Adam(learning_rate = 0.02),
                  metrics = ["mae"])

mlp_history = mlp_model.fit(Xlearn, ylearn,
                            epochs = 200,
                            batch_size = 16,
                            verbose = 0, 
                            validation_data = (Xvalidation, yvalidation))
# Out:
# (6000, 10) (6000,) (2000, 10) (2000,)
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 32)                352
#
#  output (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.bar(np.arange(1, 33), mlp_model.layers[1].weights[0].numpy()[:,0])
plt.show()

# %%
Xlearn, Xvalidation, ylearn, yvalidation = train_test_split(Xtrain, ytrain, test_size = 0.25,
                                                            random_state = 1234, shuffle = True)
print(Xlearn.shape, ylearn.shape, Xvalidation.shape, yvalidation.shape)

mlp_model = keras.models.Sequential([
    keras.layers.Dense(32, name = "hidden", activation = "relu", input_shape = (Xtrain.shape[1],)),
    keras.layers.Dense(1, name = "output", kernel_regularizer = keras.regularizers.l2(l2 = 0.1))
])
mlp_model.summary()

mlp_model.compile(loss = "mean_squared_error",
                  optimizer = keras.optimizers.Adam(learning_rate = 0.02),
                  metrics = ["mae"])

mlp_history = mlp_model.fit(Xlearn, ylearn,
                            epochs = 200,
                            batch_size = 16,
                            verbose = 0, 
                            validation_data = (Xvalidation, yvalidation))
# Out:
# (6000, 10) (6000,) (2000, 10) (2000,)
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 32)                352
#
#  output (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.bar(np.arange(1, 33), mlp_model.layers[1].weights[0].numpy()[:,0])
plt.show()
print(mlp_model.layers[1].weights[0].numpy())
# Out:
# [[ 4.11808660e-37]
#  [-1.49547101e-36]
#  [ 3.52150160e-37]
#  [ 1.28468407e-36]
#  [-7.21812292e-37]
#  [ 2.00612632e-36]
#  [ 1.55548381e-36]
#  [ 1.18650609e-36]
#  [-6.77620674e-37]
#  [-9.21009850e-37]
#  [ 1.94203555e-36]
#  [ 1.16936065e-36]
#  [ 9.08214583e-37]
#  [-1.86446254e-36]
#  [-1.24821892e-36]
#  [-2.18192063e-36]
#  [ 1.57038447e-36]
#  [ 6.47994938e-37]
#  [-4.52535550e-37]
#  [ 1.28067182e-36]
#  [-6.19008283e-37]
#  [-9.00459775e-37]
#  [-2.69263881e-36]
#  [-3.24755569e-36]
#  [ 1.19687695e-36]
#  [-4.04035601e-37]
#  [ 3.21993186e-36]
#  [ 1.13891620e-36]
#  [-4.40032336e-37]
#  [-1.13237875e-36]
#  [ 1.40445970e-36]
#  [-1.43662948e-36]]

# %%
Xlearn, Xvalidation, ylearn, yvalidation = train_test_split(Xtrain, ytrain, test_size = 0.25,
                                                            random_state = 1234, shuffle = True)
print(Xlearn.shape, ylearn.shape, Xvalidation.shape, yvalidation.shape)

mlp_model = keras.models.Sequential([
    keras.layers.Dense(32, name = "hidden", activation = "relu", input_shape = (Xtrain.shape[1],)),
    keras.layers.Dense(1, name = "output", kernel_regularizer = keras.regularizers.l1(l1 = 0.1),
                      kernel_constraint = keras.constraints.non_neg())
])
mlp_model.summary()

mlp_model.compile(loss = "mean_squared_error",
                  optimizer = keras.optimizers.Adam(learning_rate = 0.02),
                  metrics = ["mae"])

mlp_history = mlp_model.fit(Xlearn, ylearn,
                            epochs = 200,
                            batch_size = 16,
                            verbose = 0, 
                            validation_data = (Xvalidation, yvalidation))
# Out:
# (6000, 10) (6000,) (2000, 10) (2000,)
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  hidden (Dense)              (None, 32)                352
#
#  output (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________

# %%
plt.bar(np.arange(1, 33), mlp_model.layers[1].weights[0].numpy()[:,0])
plt.show()
print(mlp_model.layers[1].weights[0].numpy())

# %%
print(ylearn)
# Out:
# 368     0
# 6783    0
# 6461    0
# 1526    0
# 1709    0
#        ..
# 3276    0
# 7221    0
# 1318    1
# 723     0
# 2863    0
# Name: Exited, Length: 6000, dtype: int64

# %%
print(ylearn == 0)
print(np.mean(ylearn == 0))
print(np.mean(ylearn == 1))
# Out:
# 368      True
# 6783     True
# 6461     True
# 1526     True
# 1709     True
#         ...
# 3276     True
# 7221     True
# 1318    False
# 723      True
# 2863     True
# Name: Exited, Length: 6000, dtype: bool
# 0.7923333333333333
# 0.20766666666666667

# %%
mlp_data_binary = keras.Sequential([
    keras.layers.Input(name = "input", shape = (Xlearn.shape[1])),
    keras.layers.Flatten(name = "vectorize"),
    keras.layers.Dense(128, name = "first_relu", activation = "relu"),
    keras.layers.Dense(32, name = "second_relu", activation = "relu"),
    keras.layers.Dense(1, name = "output", activation = "sigmoid")
])

mlp_data_binary.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vectorize (Flatten)         (None, 10)                0
#
#  first_relu (Dense)          (None, 128)               1408
#
#  second_relu (Dense)         (None, 32)                4128
#
#  output (Dense)              (None, 1)                 33
#
# =================================================================
# Total params: 5,569
# Trainable params: 5,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
mlp_data_binary.compile(optimizer = "adam",
                         loss = "binary_crossentropy",
                         metrics = ["accuracy", "AUC"])

# %%
mlp_history = mlp_data_binary.fit(Xlearn, ylearn == 1,
                                   epochs = 20,
                                   class_weight = {0: np.mean(ylearn == 0),
                                                   1: np.mean(ylearn == 1)},
                                   verbose = 1, batch_size = 32,
                                   validation_data = (Xvalidation, yvalidation == 1))
# Out:
# Epoch 1/20
# 188/188 [==============================] - 0s 2ms/step - loss: 35.7476 - accuracy: 0.7555 - auc: 0.5019 - val_loss: 63.4500 - val_accuracy: 0.7975 - val_auc: 0.4984
# Epoch 2/20
# 188/188 [==============================] - 0s 2ms/step - loss: 41.8908 - accuracy: 0.7547 - auc: 0.5013 - val_loss: 56.2980 - val_accuracy: 0.7965 - val_auc: 0.4978
# Epoch 3/20
# 188/188 [==============================] - 0s 2ms/step - loss: 42.1137 - accuracy: 0.7512 - auc: 0.4956 - val_loss: 169.9249 - val_accuracy: 0.7995 - val_auc: 0.5000
# Epoch 4/20
# 188/188 [==============================] - 0s 2ms/step - loss: 48.2327 - accuracy: 0.7548 - auc: 0.4990 - val_loss: 262.3126 - val_accuracy: 0.7975 - val_auc: 0.4987
# Epoch 5/20
# 188/188 [==============================] - 0s 2ms/step - loss: 35.3380 - accuracy: 0.7568 - auc: 0.5043 - val_loss: 199.9063 - val_accuracy: 0.6890 - val_auc: 0.5178
# Epoch 6/20
# 188/188 [==============================] - 0s 2ms/step - loss: 42.1036 - accuracy: 0.7535 - auc: 0.4986 - val_loss: 93.0784 - val_accuracy: 0.7780 - val_auc: 0.4900
# Epoch 7/20
# 188/188 [==============================] - 0s 2ms/step - loss: 27.6813 - accuracy: 0.7518 - auc: 0.4962 - val_loss: 130.7088 - val_accuracy: 0.7985 - val_auc: 0.4987
# Epoch 8/20
# 188/188 [==============================] - 0s 2ms/step - loss: 36.3743 - accuracy: 0.7553 - auc: 0.5039 - val_loss: 141.4000 - val_accuracy: 0.3075 - val_auc: 0.4620
# Epoch 9/20
# 188/188 [==============================] - 0s 2ms/step - loss: 30.4298 - accuracy: 0.7562 - auc: 0.5047 - val_loss: 75.8242 - val_accuracy: 0.7995 - val_auc: 0.5000
# Epoch 10/20
# 188/188 [==============================] - 0s 2ms/step - loss: 30.3683 - accuracy: 0.7540 - auc: 0.4986 - val_loss: 72.8157 - val_accuracy: 0.7415 - val_auc: 0.5089
# Epoch 11/20
# 188/188 [==============================] - 0s 2ms/step - loss: 50.2496 - accuracy: 0.7563 - auc: 0.5024 - val_loss: 235.1163 - val_accuracy: 0.7995 - val_auc: 0.4991
# Epoch 12/20
# 188/188 [==============================] - 0s 2ms/step - loss: 49.7029 - accuracy: 0.7497 - auc: 0.4930 - val_loss: 110.6813 - val_accuracy: 0.7995 - val_auc: 0.4987
# Epoch 13/20
# 188/188 [==============================] - 0s 2ms/step - loss: 30.4176 - accuracy: 0.7508 - auc: 0.4898 - val_loss: 125.4356 - val_accuracy: 0.7995 - val_auc: 0.5000
# Epoch 14/20
# 188/188 [==============================] - 0s 2ms/step - loss: 27.0127 - accuracy: 0.7580 - auc: 0.5039 - val_loss: 264.7976 - val_accuracy: 0.7995 - val_auc: 0.4987
# Epoch 15/20
# 188/188 [==============================] - 0s 2ms/step - loss: 32.8360 - accuracy: 0.7555 - auc: 0.4991 - val_loss: 198.6707 - val_accuracy: 0.5375 - val_auc: 0.4064
# Epoch 16/20
# 188/188 [==============================] - 0s 2ms/step - loss: 32.1193 - accuracy: 0.7528 - auc: 0.5004 - val_loss: 43.9530 - val_accuracy: 0.6555 - val_auc: 0.5486
# Epoch 17/20
# 188/188 [==============================] - 0s 2ms/step - loss: 40.0113 - accuracy: 0.7525 - auc: 0.4924 - val_loss: 510.7406 - val_accuracy: 0.7995 - val_auc: 0.4987
# Epoch 18/20
# 188/188 [==============================] - 0s 2ms/step - loss: 37.3957 - accuracy: 0.7538 - auc: 0.4981 - val_loss: 302.9312 - val_accuracy: 0.7995 - val_auc: 0.5000
# Epoch 19/20
# 188/188 [==============================] - 0s 2ms/step - loss: 31.4264 - accuracy: 0.7572 - auc: 0.5054 - val_loss: 19.3590 - val_accuracy: 0.7470 - val_auc: 0.5123
# Epoch 20/20
# 188/188 [==============================] - 0s 2ms/step - loss: 26.4507 - accuracy: 0.7533 - auc: 0.4986 - val_loss: 148.7202 - val_accuracy: 0.7995 - val_auc: 0.5000

# %%
print(mlp_data_binary.evaluate(Xlearn, ylearn == 1))
print(mlp_data_binary.evaluate(Xvalidation, yvalidation == 1))
print(mlp_data_binary.evaluate(Xtest, ytest == 1))
# Out:
# 188/188 [==============================] - 0s 1ms/step - loss: 152.4830 - accuracy: 0.7923 - auc: 0.5001
# [152.4829559326172, 0.7923333048820496, 0.5000858306884766]
# 63/63 [==============================] - 0s 993us/step - loss: 148.7202 - accuracy: 0.7995 - auc: 0.5000
# [148.72018432617188, 0.7994999885559082, 0.5]
# 63/63 [==============================] - 0s 1ms/step - loss: 141.8712 - accuracy: 0.8050 - auc: 0.4991
# [141.8711700439453, 0.8050000071525574, 0.49906831979751587]

# %%
plt.plot(mlp_history.history["loss"])
plt.plot(mlp_history.history["val_loss"])
plt.show()

# %%
plt.plot(mlp_history.history["accuracy"])
plt.plot(mlp_history.history["val_accuracy"])
plt.show()

# %%
plt.plot(mlp_history.history["auc"])
plt.plot(mlp_history.history["val_auc"])
plt.show()

# %%
input_layer = keras.layers.Input(name = "input", 
                                 shape = (Xlearn.shape[1]))

base_model = keras.layers.Flatten()(input_layer)
base_model = keras.layers.Dense(128, name = "base_relu",
                                activation = "relu")(base_model)
base_model = keras.layers.Dropout(rate = 0.5, 
                                  name = "base_dropout")(base_model)

digit_model = keras.layers.Dense(32, name = "digits_relu",
                                 activation = "relu")(base_model)
digit_model = keras.layers.Dense(10, name = "digits_output",
                                 activation = "relu")(digit_model)

oddeven_model = keras.layers.Dense(32, name = "oddeven_relu",
                                   activation = "relu")(base_model)
oddeven_model = keras.layers.Dense(1, name = "oddeven_output",
                                   activation = "sigmoid")(oddeven_model)

complete_model = keras.models.Model(inputs = input_layer,
                                    outputs = [digit_model, oddeven_model])

keras.utils.plot_model(complete_model, show_shapes = True,
                       show_dtype = True,
                       show_layer_activations = True,
                       show_layer_names = True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
pip install pydot
# Out:
# Requirement already satisfied: pydot in c:\users\asus\anaconda3\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\asus\anaconda3\anaconda3\lib\site-packages (from pydot) (3.0.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
complete_model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 10)]         0           []
#
#  flatten_3 (Flatten)            (None, 10)           0           ['input[0][0]']
#
#  base_relu (Dense)              (None, 128)          1408        ['flatten_3[0][0]']
#
#  base_dropout (Dropout)         (None, 128)          0           ['base_relu[0][0]']
#
#  digits_relu (Dense)            (None, 32)           4128        ['base_dropout[0][0]']
#
#  oddeven_relu (Dense)           (None, 32)           4128        ['base_dropout[0][0]']
#
#  digits_output (Dense)          (None, 10)           330         ['digits_relu[0][0]']
#
#  oddeven_output (Dense)         (None, 1)            33          ['oddeven_relu[0][0]']
#
# ==================================================================================================
# Total params: 10,027
# Trainable params: 10,027
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
complete_model.compile(optimizer = "adam",
                       loss = {"digits_output": "sparse_categorical_crossentropy",
                               "oddeven_output": "binary_crossentropy"},
                       loss_weights = {"digits_output": 0.5, 
                                       "oddeven_output": 0.5},
                       metrics = {"digits_output": ["accuracy"],
                                  "oddeven_output": ["accuracy", "AUC"]}
                      )

# %%
multi_output_history = complete_model.fit(Xlearn, 
                                          {"digits_output": ylearn,
                                           "oddeven_output": ylearn == 1},
                                          epochs = 20,
                                          batch_size = 32,
                                          verbose = 1,
                                          validation_data = (Xvalidation, {"digits_output": yvalidation,
                                           "oddeven_output": yvalidation == 1}))
# Out:
# Epoch 1/20
# 188/188 [==============================] - 0s 2ms/step - loss: 2.0439 - digits_output_loss: 2.7178 - oddeven_output_loss: 1.3701 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.3943 - oddeven_output_auc: 0.5089 - val_loss: 2.0946 - val_digits_output_loss: 3.0352 - val_oddeven_output_loss: 1.1540 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.5040 - val_oddeven_output_auc: 0.4741
# Epoch 2/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.9745 - digits_output_loss: 2.8415 - oddeven_output_loss: 1.1076 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.5217 - oddeven_output_auc: 0.4981 - val_loss: 2.0597 - val_digits_output_loss: 2.5270 - val_oddeven_output_loss: 1.5925 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7980 - val_oddeven_output_auc: 0.5429
# Epoch 3/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.7874 - digits_output_loss: 2.4843 - oddeven_output_loss: 1.0904 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7723 - oddeven_output_auc: 0.5159 - val_loss: 1.6414 - val_digits_output_loss: 2.4879 - val_oddeven_output_loss: 0.7948 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.5359
# Epoch 4/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.6668 - digits_output_loss: 2.4687 - oddeven_output_loss: 0.8650 - digits_output_accuracy: 0.7920 - oddeven_output_accuracy: 0.7770 - oddeven_output_auc: 0.5197 - val_loss: 1.5672 - val_digits_output_loss: 2.4753 - val_oddeven_output_loss: 0.6591 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.5298
# Epoch 5/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.5987 - digits_output_loss: 2.4536 - oddeven_output_loss: 0.7437 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7835 - oddeven_output_auc: 0.5108 - val_loss: 1.6481 - val_digits_output_loss: 2.4684 - val_oddeven_output_loss: 0.8278 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7540 - val_oddeven_output_auc: 0.5144
# Epoch 6/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.5817 - digits_output_loss: 2.4496 - oddeven_output_loss: 0.7137 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7848 - oddeven_output_auc: 0.4829 - val_loss: 1.6910 - val_digits_output_loss: 2.4810 - val_oddeven_output_loss: 0.9009 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.4844
# Epoch 7/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.5853 - digits_output_loss: 2.4505 - oddeven_output_loss: 0.7200 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7838 - oddeven_output_auc: 0.4971 - val_loss: 1.5475 - val_digits_output_loss: 2.4419 - val_oddeven_output_loss: 0.6532 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.4864
# Epoch 8/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.5263 - digits_output_loss: 2.4047 - oddeven_output_loss: 0.6480 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7860 - oddeven_output_auc: 0.4823 - val_loss: 1.4622 - val_digits_output_loss: 2.4051 - val_oddeven_output_loss: 0.5194 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.5015
# Epoch 9/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.5074 - digits_output_loss: 2.3955 - oddeven_output_loss: 0.6193 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7867 - oddeven_output_auc: 0.5002 - val_loss: 1.4437 - val_digits_output_loss: 2.3820 - val_oddeven_output_loss: 0.5054 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.5037
# Epoch 10/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4902 - digits_output_loss: 2.3848 - oddeven_output_loss: 0.5957 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7875 - oddeven_output_auc: 0.4822 - val_loss: 1.4397 - val_digits_output_loss: 2.3740 - val_oddeven_output_loss: 0.5054 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.4954
# Epoch 11/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4713 - digits_output_loss: 2.3814 - oddeven_output_loss: 0.5612 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7880 - oddeven_output_auc: 0.4877 - val_loss: 1.4665 - val_digits_output_loss: 2.3748 - val_oddeven_output_loss: 0.5582 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7735 - val_oddeven_output_auc: 0.5015
# Epoch 12/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4484 - digits_output_loss: 2.3561 - oddeven_output_loss: 0.5407 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7888 - oddeven_output_auc: 0.4980 - val_loss: 1.4313 - val_digits_output_loss: 2.3406 - val_oddeven_output_loss: 0.5220 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7830 - val_oddeven_output_auc: 0.4972
# Epoch 13/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4437 - digits_output_loss: 2.3480 - oddeven_output_loss: 0.5394 - digits_output_accuracy: 0.7922 - oddeven_output_accuracy: 0.7892 - oddeven_output_auc: 0.5002 - val_loss: 1.4243 - val_digits_output_loss: 2.3463 - val_oddeven_output_loss: 0.5022 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.5007
# Epoch 14/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4370 - digits_output_loss: 2.3529 - oddeven_output_loss: 0.5211 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7900 - oddeven_output_auc: 0.4984 - val_loss: 1.4189 - val_digits_output_loss: 2.3360 - val_oddeven_output_loss: 0.5019 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.4998
# Epoch 15/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4397 - digits_output_loss: 2.3538 - oddeven_output_loss: 0.5257 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7907 - oddeven_output_auc: 0.4933 - val_loss: 1.4297 - val_digits_output_loss: 2.3394 - val_oddeven_output_loss: 0.5200 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.4993
# Epoch 16/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4476 - digits_output_loss: 2.3520 - oddeven_output_loss: 0.5431 - digits_output_accuracy: 0.7922 - oddeven_output_accuracy: 0.7897 - oddeven_output_auc: 0.4975 - val_loss: 1.4287 - val_digits_output_loss: 2.3256 - val_oddeven_output_loss: 0.5319 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7835 - val_oddeven_output_auc: 0.4983
# Epoch 17/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4155 - digits_output_loss: 2.3167 - oddeven_output_loss: 0.5143 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7915 - oddeven_output_auc: 0.4941 - val_loss: 1.4146 - val_digits_output_loss: 2.3279 - val_oddeven_output_loss: 0.5014 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.4956
# Epoch 18/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4337 - digits_output_loss: 2.3506 - oddeven_output_loss: 0.5168 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7910 - oddeven_output_auc: 0.4940 - val_loss: 1.4085 - val_digits_output_loss: 2.3158 - val_oddeven_output_loss: 0.5012 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.5029
# Epoch 19/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4261 - digits_output_loss: 2.3354 - oddeven_output_loss: 0.5168 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7918 - oddeven_output_auc: 0.4969 - val_loss: 1.4055 - val_digits_output_loss: 2.3095 - val_oddeven_output_loss: 0.5015 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.4996
# Epoch 20/20
# 188/188 [==============================] - 0s 2ms/step - loss: 1.4200 - digits_output_loss: 2.3271 - oddeven_output_loss: 0.5129 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7917 - oddeven_output_auc: 0.4874 - val_loss: 1.3996 - val_digits_output_loss: 2.2980 - val_oddeven_output_loss: 0.5011 - val_digits_output_accuracy: 0.7995 - val_oddeven_output_accuracy: 0.7995 - val_oddeven_output_auc: 0.5007

# %%
print(complete_model.evaluate(Xlearn, {"digits_output": ylearn,
                                       "oddeven_output": ylearn == 1}))
print(complete_model.evaluate(Xvalidation, {"digits_output": yvalidation,
                                     "oddeven_output": yvalidation == 1}))
print(complete_model.evaluate(Xtest, {"digits_output": ytest,
                                      "oddeven_output": ytest == 1}))
# Out:
# 188/188 [==============================] - 0s 1ms/step - loss: 1.4319 - digits_output_loss: 2.3521 - oddeven_output_loss: 0.5117 - digits_output_accuracy: 0.7923 - oddeven_output_accuracy: 0.7923 - oddeven_output_auc: 0.4938
# [1.4318727254867554, 2.352088451385498, 0.5116552114486694, 0.7923333048820496, 0.7923333048820496, 0.4937978982925415]
# 63/63 [==============================] - 0s 1ms/step - loss: 1.3996 - digits_output_loss: 2.2980 - oddeven_output_loss: 0.5011 - digits_output_accuracy: 0.7995 - oddeven_output_accuracy: 0.7995 - oddeven_output_auc: 0.5007
# [1.3995541334152222, 2.2979798316955566, 0.5011280179023743, 0.7994999885559082, 0.7994999885559082, 0.5007314085960388]
# 63/63 [==============================] - 0s 1ms/step - loss: 1.4385 - digits_output_loss: 2.3797 - oddeven_output_loss: 0.4972 - digits_output_accuracy: 0.8050 - oddeven_output_accuracy: 0.8050 - oddeven_output_auc: 0.4892
# [1.4384735822677612, 2.3797214031219482, 0.49722570180892944, 0.8050000071525574, 0.8050000071525574, 0.4892299771308899]
